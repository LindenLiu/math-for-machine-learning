# %% [markdown]
# ## Poisson Distribution
# In the case we don't know the probability of event, but know average of the event in given internval (usually time). lambda is the interval.
#
# P(k) = (lambda)^k * e^(-k) / k!

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
t = np.random.poisson(5, size=1000)
p_d = np.bincount(t)
print(t.max())
print(p_d)
print(p_d / p_d.sum())
plt.plot(p_d)
# Out:
# 15
# [  8  38  91 139 170 172 133 103  79  47  14   3   2   0   0   1]
# [0.008 0.038 0.091 0.139 0.17  0.172 0.133 0.103 0.079 0.047 0.014 0.003
#  0.002 0.    0.    0.001]

# %% [markdown]
# ## Fast Loaded Dice Roller
# Used to Sample Integers according arbitary weights
#
# [github](https://github.com/probsys/fast-loaded-dice-roller)

# %%
from fldr import fldr_preprocess_float_c, fldr_sample

x = fldr_preprocess_float_c([0.6, 0.2, 0.1, 0.1])
s = [fldr_sample(x) for _ in range(1000)]
s = np.bincount(s)
print(s)

from scipy.misc import face
im = face(True)
b = np.bincount(im.ravel(), minlength=256)
b = b / b.sum()
x = fldr_preprocess_float_c(list(b))
q = [fldr_sample(x) for _ in range(25000)]
q = np.bincount(q)
q = q / q.sum()

plt.plot(q)
plt.plot(b, '--')
plt.show()
# Out:
# [611 207  97  85]
# /tmp/ipykernel_112192/1375348177.py:9: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   im = face(True)
